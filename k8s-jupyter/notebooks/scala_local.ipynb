// %%
import $ivy.`org.apache.spark::spark-connect-client-jvm:4.0.0`
// Out:
// import $ivy.$

// %%
import org.apache.spark.sql.SparkSession

val spark = SparkSession.builder
    .remote("sc://localhost:15002")
    .getOrCreate()

val df = spark.range(5)
df.show()
// Out:
// 1 deprecation (since 2.13.3); re-run enabling -deprecation for details, or try -help
// +---+
// | id|
// +---+
// |  0|
// |  1|
// |  2|
// |  3|
// |  4|
// +---+
// import org.apache.spark.sql.SparkSession
// spark: SparkSession = org.apache.spark.sql.connect.SparkSession@163ec42e
// df: org.apache.spark.sql.Dataset[java.lang.Long] = [id: bigint]

// %%
import com.chen.guo.WordCountEMR

WordCountEMR.main(Array("arg1", "arg2"))
// Out:
// cmd3.sc:1: object chen is not a member of package com
// import com.chen.guo.WordCountEMR
//            ^
// cmd3.sc:3: not found: value WordCountEMR
// val res3_1 = WordCountEMR.main(Array("arg1", "arg2"))
//              ^
// Compilation Failed

// %%
spark.close()
