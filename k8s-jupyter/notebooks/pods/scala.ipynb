// %%
// Add a Maven dependency (downloads if needed)
import $ivy.`org.apache.spark::spark-connect-client-jvm:4.0.0`
import $ivy.`org.apache.spark::spark-sql:4.0.0`

// $cp: Ammonite "magic import" that stands for classpath
import $cp.`/custom-jars2/word-count.jar`


// Add a source file
// import $file.`/path/to/MyScript.sc`

// Reference a URL
// import $url.`https://example.com/script.sc`
// Out:
//   Cell In[2], line 1
//     // Add a Maven dependency (downloads if needed)
//     ^
// SyntaxError: invalid syntax

// %%
val cls = Class.forName("org.apache.spark.sql.SparkSession")
println(s"SparkSession loaded from: ${cls.getProtectionDomain.getCodeSource.getLocation}")
// Out:
// java.lang.UnsupportedClassVersionError: org/apache/spark/sql/SparkSession has been compiled by a more recent version of the Java Runtime (class file version 61.0), this version of the Java Runtime only recognizes class file versions up to 52.0
//   java.lang.ClassLoader.defineClass1(Native Method)
//   java.lang.ClassLoader.defineClass(ClassLoader.java:756)
//   java.security.SecureClassLoader.defineClass(SecureClassLoader.java:142)
//   java.net.URLClassLoader.defineClass(URLClassLoader.java:473)
//   java.net.URLClassLoader.access$100(URLClassLoader.java:74)
//   java.net.URLClassLoader$1.run(URLClassLoader.java:369)
//   java.net.URLClassLoader$1.run(URLClassLoader.java:363)
//   java.security.AccessController.doPrivileged(Native Method)
//   java.net.URLClassLoader.findClass(URLClassLoader.java:362)
//   ammonite.runtime.SpecialClassLoader.findClass(ClassLoaders.scala:250)
//   java.lang.ClassLoader.loadClass(ClassLoader.java:418)
//   java.lang.ClassLoader.loadClass(ClassLoader.java:351)
//   java.lang.Class.forName0(Native Method)
//   java.lang.Class.forName(Class.java:264)
//   ammonite.$sess.cmd14$Helper.<init>(cmd14.sc:1)
//   ammonite.$sess.cmd14$.<clinit>(cmd14.sc:7)

// %%
import com.chen.guo.WordCountSparkConnect

WordCountSparkConnect.main(Array("arg1", "arg2"))
// Out:
// Received argument: arg1
// Received argument: arg2
// java.lang.NoClassDefFoundError: org/apache/spark/sql/SparkSession$
//   com.chen.guo.WordCountSparkConnect$.delayedEndpoint$com$chen$guo$WordCountSparkConnect$1(WordCountSparkConnect.scala:11)
//   com.chen.guo.WordCountSparkConnect$delayedInit$body.apply(WordCountSparkConnect.scala:7)
//   scala.Function0.apply$mcV$sp(Function0.scala:42)
//   scala.Function0.apply$mcV$sp$(Function0.scala:42)
//   scala.runtime.AbstractFunction0.apply$mcV$sp(AbstractFunction0.scala:17)
//   scala.App.$anonfun$main$1(App.scala:98)
//   scala.App.$anonfun$main$1$adapted(App.scala:98)
//   scala.collection.IterableOnceOps.foreach(IterableOnce.scala:619)
//   scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:617)
//   scala.collection.AbstractIterable.foreach(Iterable.scala:935)
//   scala.App.main(App.scala:98)
//   scala.App.main$(App.scala:96)
//   com.chen.guo.WordCountSparkConnect$.main(WordCountSparkConnect.scala:7)
//   ammonite.$sess.cmd13$Helper.<init>(cmd13.sc:3)
//   ammonite.$sess.cmd13$.<clinit>(cmd13.sc:7)
