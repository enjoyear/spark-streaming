# %%
pip install pyspark kubernetes pyyaml
# Out:
# Requirement already satisfied: pyspark in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (4.0.1)
# Requirement already satisfied: kubernetes in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (34.1.0)
# Requirement already satisfied: pyyaml in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (6.0.3)
# Requirement already satisfied: py4j==0.10.9.9 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from pyspark) (0.10.9.9)
# Requirement already satisfied: certifi>=14.05.14 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (2025.10.5)
# Requirement already satisfied: six>=1.9.0 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (1.9.0)
# Requirement already satisfied: requests in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (2.32.5)
# Requirement already satisfied: requests-oauthlib in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from kubernetes) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from requests->kubernetes) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from requests->kubernetes) (3.11)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from requests-oauthlib->kubernetes) (3.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/chenguo/.pyenv/versions/3.12.11/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes) (0.6.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from kubernetes import client, config
import yaml

# Load kubeconfig
config.load_kube_config()

# Define SparkApplication as YAML string
spark_app_yaml = """
apiVersion: sparkoperator.k8s.io/v1beta2
kind: SparkApplication
metadata:
  name: spark-pi
  namespace: default
spec:
  type: Scala
  mode: cluster
  image: docker.io/library/spark:4.0.0
  imagePullPolicy: IfNotPresent
  mainClass: org.apache.spark.examples.SparkPi
  mainApplicationFile: local:///opt/spark/examples/jars/spark-examples.jar
  arguments:
  - "5000"
  sparkVersion: 4.0.0
  sparkConf:
    spark.kubernetes.executor.deleteOnTermination: "false" # Keep the executor pods after completion to inspect the logs
  driver:
    labels:
      version: 4.0.0
    cores: 1
    memory: 512m
    serviceAccount: spark-operator-spark
    securityContext:
      capabilities:
        drop:
        - ALL
      runAsGroup: 185
      runAsUser: 185
      runAsNonRoot: true
      allowPrivilegeEscalation: false
      seccompProfile:
        type: RuntimeDefault
  executor:
    labels:
      version: 4.0.0
    instances: 1
    cores: 1
    memory: 512m
    securityContext:
      capabilities:
        drop:
        - ALL
      runAsGroup: 185
      runAsUser: 185
      runAsNonRoot: true
      allowPrivilegeEscalation: false
      seccompProfile:
        type: RuntimeDefault
"""

# Parse YAML to Python dict
spark_app = yaml.safe_load(spark_app_yaml)

# Create the SparkApplication
api = client.CustomObjectsApi()
api.create_namespaced_custom_object(
    group="sparkoperator.k8s.io",
    version="v1beta2",
    namespace="default",
    plural="sparkapplications",
    body=spark_app
)
# Out:
# {'apiVersion': 'sparkoperator.k8s.io/v1beta2',
#  'kind': 'SparkApplication',
#  'metadata': {'creationTimestamp': '2025-11-09T03:43:12Z',
#   'generation': 1,
#   'managedFields': [{'apiVersion': 'sparkoperator.k8s.io/v1beta2',
#     'fieldsType': 'FieldsV1',
#     'fieldsV1': {'f:spec': {'.': {},
#       'f:arguments': {},
#       'f:driver': {'.': {},
#        'f:cores': {},
#        'f:labels': {'.': {}, 'f:version': {}},
#        'f:memory': {},
#        'f:securityContext': {'.': {},
#         'f:allowPrivilegeEscalation': {},
#         'f:capabilities': {'.': {}, 'f:drop': {}},
#         'f:runAsGroup': {},
#         'f:runAsNonRoot': {},
#         'f:runAsUser': {},
#         'f:seccompProfile': {'.': {}, 'f:type': {}}},
#        'f:serviceAccount': {}},
#       'f:executor': {'.': {},
#        'f:cores': {},
#        'f:instances': {},
#        'f:labels': {'.': {}, 'f:version': {}},
#        'f:memory': {},
#        'f:securityContext': {'.': {},
#         'f:allowPrivilegeEscalation': {},
#         'f:capabilities': {'.': {}, 'f:drop': {}},
#         'f:runAsGroup': {},
#         'f:runAsNonRoot': {},
#         'f:runAsUser': {},
#         'f:seccompProfile': {'.': {}, 'f:type': {}}}},
#       'f:image': {},
#       'f:imagePullPolicy': {},
#       'f:mainApplicationFile': {},
#       'f:mainClass': {},
#       'f:mode': {},
#       'f:sparkConf': {'.': {},
#        'f:spark.kubernetes.executor.deleteOnTermination': {}},
#       'f:sparkVersion': {},
#       'f:type': {}}},
#     'manager': 'OpenAPI-Generator',
#     'operation': 'Update',
#     'time': '2025-11-09T03:43:12Z'}],
#   'name': 'spark-pi',
#   'namespace': 'default',
#   'resourceVersion': '639297',
#   'uid': '19825e0d-87c6-489e-93e7-a6490e242c91'},
#  'spec': {'arguments': ['5000'],
#   'deps': {},
#   'driver': {'cores': 1,
#    'labels': {'version': '4.0.0'},
#    'memory': '512m',
#    'securityContext': {'allowPrivilegeEscalation': False,
#     'capabilities': {'drop': ['ALL']},
#     'runAsGroup': 185,
#     'runAsNonRoot': True,
#     'runAsUser': 185,
#     'seccompProfile': {'type': 'RuntimeDefault'}},
#    'serviceAccount': 'spark-operator-spark'},
#   'executor': {'cores': 1,
#    'instances': 1,
#    'labels': {'version': '4.0.0'},
#    'memory': '512m',
#    'securityContext': {'allowPrivilegeEscalation': False,
#     'capabilities': {'drop': ['ALL']},
#     'runAsGroup': 185,
#     'runAsNonRoot': True,
#     'runAsUser': 185,
#     'seccompProfile': {'type': 'RuntimeDefault'}}},
#   'image': 'docker.io/library/spark:4.0.0',
#   'imagePullPolicy': 'IfNotPresent',
#   'mainApplicationFile': 'local:///opt/spark/examples/jars/spark-examples.jar',
#   'mainClass': 'org.apache.spark.examples.SparkPi',
#   'mode': 'cluster',
#   'restartPolicy': {'type': 'Never'},
#   'sparkConf': {'spark.kubernetes.executor.deleteOnTermination': 'false'},
#   'sparkVersion': '4.0.0',
#   'type': 'Scala'}}
